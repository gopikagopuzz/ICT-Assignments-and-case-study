# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/car_age_price.csv')
data.head()
# Out:
#    Year   Price
# 0  2018  465000
# 1  2019  755000
# 2  2019  700000
# 3  2018  465000
# 4  2018  465000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    112 non-null    int64
#  1   Price   112 non-null    int64
# dtypes: int64(2)
# memory usage: 1.9 KB

# %%
x=data.drop('Price',axis=1)
y=data['Price']

# %%
x
# Out:
#      Year
# 0    2018
# 1    2019
# 2    2019
# 3    2018
# 4    2018
# ..    ...
# 107  2016
# 108  2014
# 109  2015
# 110  2016
# 111  2015
#
# [112 rows x 1 columns]

# %%
y
# Out:
# 0      465000
# 1      755000
# 2      700000
# 3      465000
# 4      465000
#         ...
# 107    375000
# 108    300000
# 109    425000
# 110    420000
# 111    425000
# Name: Price, Length: 112, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn import linear_model
lr = linear_model.LinearRegression()

# %%
model =lr.fit(x_train,y_train)

# %%
pre = model.predict(x_test)

# %%
pre
# Out:
# array([599223.07304104, 505265.04214995, 552244.05759549, 552244.05759549,
#        552244.05759549, 411307.01125886, 505265.04214995, 552244.05759549,
#        599223.07304104, 599223.07304104, 317348.98036776, 505265.04214995,
#        411307.01125886, 646202.08848657, 552244.05759549, 599223.07304104,
#        317348.98036776, 411307.01125886, 505265.04214995, 505265.04214995,
#        505265.04214995, 505265.04214995, 505265.04214995, 505265.04214995,
#        505265.04214995, 505265.04214995, 411307.01125886, 411307.01125886])

# %%
from sklearn.metrics import r2_score, mean_squared_error
# Calculate r2 score
r2 = r2_score(y_test, pre)

# Calculate Mean Squared Error
mse = mean_squared_error(y_test, pre)



print(f"R-squared: {r2}")
print(f"Mean Squared Error: {mse}")
# Out:
# R-squared: 0.4347961632108023
# Mean Squared Error: 3878767151.073449

# %%
#Linear prediction
predicted_price = lr.predict([[2022]])
print(f"Predicted price for a 2022 model: {predicted_price[0]}")
# Out:
# Predicted price for a 2022 model: 740160.1193776578
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#lasso model
from sklearn.linear_model import Lasso
lasso_model = Lasso(alpha=1.0)
lasso_model.fit(x_train, y_train)
lasso_predictions = lasso_model.predict(x_test)

# %%
# For Lasso Regression


# Calculate r2 score
lasso_r2 = r2_score(y_test, lasso_predictions)


# Calculate Mean Squared Error
lasso_mse = mean_squared_error(y_test, lasso_predictions)



print("\nLasso Regression:")
print(f"R-squared: {lasso_r2}")
print(f"Mean Squared Error: {lasso_mse}")
print(f"Root Mean Squared Error: {lasso_rmse}")
# Out:
# Lasso Regression:
# R-squared: 0.4348007175862566
# Mean Squared Error: 3878735896.222091
# Root Mean Squared Error: 62279.49820143135

# %%
# Lasso prediction
predicted_price = lasso_model.predict([[2022]])
print(f"Predicted price for a 2022 model: {predicted_price[0]}")
# Out:
# Predicted price for a 2022 model: 740157.9570014179
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
